# %%
import dash
import dash_bootstrap_components as dbc
import numpy as np
import pandas as pd
import plotly.express as px
from dash import Input, Output, dcc, html
from sklearn.linear_model import QuantileRegressor

import plotly.graph_objects as go

# %%
data_source_color = {
    "재무상태": "Olive",
    "손익계산": "DarkGreen",
    "현금흐름": "DarkSlateBlue",
    "주식": "Gray",
    "거래소": "Brown",
    "PerShare": "Aqua",
    "Multiple": "CadetBlue",
    "안정성": "Crimson",
    "수익성": "DeepPink",
}
data_source = data_source_color.keys()

data_years = ["2018", "2019", "2020", "2021", "2022"]

# %%
# load function formula data
function_data = pd.read_excel("../data/기업정보 데이터 함수식.xlsx")
function_data["분류"] = function_data["분류"].fillna(method="ffill")

# %%
# make default data
xls = pd.ExcelFile("../data/기업데이터수집_2차전지업체_230526.xlsx")

# %%
def cal_ratio(
    df,
    name: str,
    numerator: str,
    denominator: str = np.nan,  # If np.nan, use the previous numerator value
    to_percentage: bool = False,
    data_years: list = ["2018", "2019", "2020", "2021", "2022"],
) -> pd.DataFrame:
    if denominator is np.nan:
        result = df.loc[df.항목명 == numerator, data_years]
        denominator = result.copy()
        denominator.columns = [str(int(cnt) + 1) for cnt in data_years]
        result = result / denominator.replace(0, np.nan)  # prevent ZeroDivisionError
        result = result[data_years]
    else:
        result = pd.DataFrame(
            df.loc[df.항목명 == numerator, data_years].values
            / df.loc[df.항목명 == denominator, data_years]
            .replace(0, np.nan)
            .values,  # prevent ZeroDivisionError,
            columns=data_years,
        )

    if to_percentage:
        result *= 100

    if result.empty:
        result = pd.DataFrame({column: [np.nan] for column in result.columns})

    result["항목명"] = name

    return result

# %%
data = {}
for cnt in xls.sheet_names:
    df = pd.read_excel(xls, cnt)
    df.name = cnt
    df = df.loc[df.분류.isin(data_source), ["항목명", *data_years]]
    df_n_stocks = df.loc[df.항목명.isin(["발행주식수(보통주)", "발행주식수(우선주)"]), data_years].sum()
    df_n_stocks["항목명"] = "발행주식수"

    df = pd.concat([df, pd.DataFrame(df_n_stocks).T], ignore_index=True)

    # concat ratio values
    for _, row in function_data.iterrows():
        df = pd.concat(
            [
                df,
                cal_ratio(
                    df,
                    name=row["name"],
                    numerator=row["numerator"],
                    denominator=row["denominator"],
                    to_percentage=row["to_percentage"],
                ),
            ],
            ignore_index=True,
        )
    data[cnt] = df

# %%
data
# Out:
# {'엘지에너지솔루션(연결)':           항목명 2018 2019      2020        2021        2022
#  0        자산총계    0    0  19941795    23764137    38299445
#  1        유동자산    0    0   9085706     9535827    18804269
#  2    현금및현금성자산    0    0   1493145     1282880     5937967
#  3        매출채권    0    0   2931150     2914458     4771846
#  4      단기금융상품    0    0    600000        1067           0
#  ..        ...  ...  ...       ...         ...         ...
#  71     매출액증가율  NaN  NaN       NaN         NaN         NaN
#  72    영업이익증가율  NaN  NaN       NaN -161.713026  157.939672
#  73  EBITDA증가율  NaN  NaN       NaN  -471.65929  123.080255
#  74     EPS증가율  NaN  NaN       NaN         NaN         NaN
#  75     BPS증가율  NaN  NaN       NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '삼성SDI(연결)':           항목명         2018         2019         2020        2021         2022
#  0        자산총계  19349721.18  19852096.45  21534232.27    25833193  30257525.17
#  1        유동자산   5519342.21    5181414.9   5657405.17  7444907.07   9651702.38
#  2    현금및현금성자산   1516585.55   1156295.42   1545974.32  2325692.35   2614271.85
#  3        매출채권   1496380.97    1772966.3   1605658.48  1945662.58   2419188.86
#  4      단기금융상품     95216.45     88667.41       122740    107066.9     483069.1
#  ..        ...          ...          ...          ...         ...          ...
#  71     매출액증가율          NaN          NaN          NaN         NaN          NaN
#  72    영업이익증가율          NaN    64.642721   145.255204  159.022698   169.356906
#  73  EBITDA증가율          NaN    89.851339    130.94904  152.300751   140.594347
#  74     EPS증가율          NaN          NaN          NaN         NaN          NaN
#  75     BPS증가율          NaN          NaN          NaN         NaN          NaN
#
#  [76 rows x 6 columns],
#  '에스케이온(연결)':           항목명 2018 2019 2020         2021         2022
#  0        자산총계    0    0    0  10966346.85  21259859.59
#  1        유동자산    0    0    0   4020059.83   8871126.46
#  2    현금및현금성자산    0    0    0   1164357.54    3466731.5
#  3        매출채권    0    0    0    525910.73   1241800.84
#  4      단기금융상품    0    0    0    470037.29     68245.46
#  ..        ...  ...  ...  ...          ...          ...
#  71     매출액증가율  NaN  NaN  NaN          NaN          NaN
#  72    영업이익증가율  NaN  NaN  NaN          NaN   341.918424
#  73  EBITDA증가율  NaN  NaN  NaN          NaN   278.137337
#  74     EPS증가율  NaN  NaN  NaN          NaN          NaN
#  75     BPS증가율  NaN  NaN  NaN          NaN          NaN
#
#  [76 rows x 6 columns],
#  '포스코퓨처엠(연결)':           항목명       2018        2019        2020        2021        2022
#  0        자산총계  947629.18  1730132.57  2088053.32   3922480.3  4637476.14
#  1        유동자산  439946.01   649644.63   810610.65  2084228.05  2037518.47
#  2    현금및현금성자산  120477.21    36746.68   121680.35    72279.98   281380.44
#  3        매출채권  180856.82   208901.92   275000.41   239230.13   288251.21
#  4      단기금융상품   13274.76     5382.95     4924.34    16817.77    28161.74
#  ..        ...        ...         ...         ...         ...         ...
#  71     매출액증가율        NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율        NaN   84.530039    67.07439  201.885808  136.322545
#  73  EBITDA증가율        NaN   82.716656    65.78723  209.809146   99.534657
#  74     EPS증가율        NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율        NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '에코프로비엠(연결)':           항목명           2018           2019        2020        2021
#  0        자산총계  464451.919535  650356.539054   798986.12  1425857.75  \
#  1        유동자산  211613.399602  245507.156234   304796.63    739143.5
#  2    현금및현금성자산    9552.861552   20105.505889    59234.18   104647.51
#  3        매출채권   61188.504689   65488.471803    79193.56   247398.85
#  4      단기금융상품            100              0           0         550
#  ..        ...            ...            ...         ...         ...
#  71     매출액증가율            NaN            NaN         NaN         NaN
#  72    영업이익증가율            NaN      73.736875  147.715479  210.028779
#  73  EBITDA증가율            NaN      85.404837  144.546051  182.877963
#  74     EPS증가율            NaN            NaN         NaN         NaN
#  75     BPS증가율            NaN            NaN         NaN         NaN
#
#            2022
#  0   3374166.38
#  1    2274293.4
#  2     320363.5
#  3     877390.7
#  4        30000
#  ..         ...
#  71         NaN
#  72  330.933307
#  73  250.860857
#  74         NaN
#  75         NaN
#
#  [76 rows x 6 columns],
#  '한솔케미칼(연결)':           항목명       2018        2019        2020        2021       2022
#  0        자산총계  791727.78   939194.15    999200.5  1197174.77  1253310.6
#  1        유동자산  156519.81   306707.46   307726.38   411301.74  386120.25
#  2    현금및현금성자산   14321.31    57077.03    98150.17    66050.68    99069.6
#  3        매출채권   69324.97    70879.74    61402.72    93096.01   92537.76
#  4      단기금융상품    4948.07    63783.69       55000   131000.09   44889.28
#  ..        ...        ...         ...         ...         ...        ...
#  71     매출액증가율        NaN         NaN         NaN         NaN        NaN
#  72    영업이익증가율        NaN  118.771659  136.688239  130.112286  94.084278
#  73  EBITDA증가율        NaN   122.16113    125.6092  125.244589  96.057239
#  74     EPS증가율        NaN         NaN         NaN         NaN        NaN
#  75     BPS증가율        NaN         NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '후성(연결)':           항목명       2018       2019        2020         2021        2022
#  0        자산총계  441480.96  528907.91   540108.38    616334.42   933755.42
#  1        유동자산  121860.45  131110.62   132927.91    182189.88   345182.99
#  2    현금및현금성자산   32737.07   40122.04    49803.23     39352.36    78961.32
#  3        매출채권   36638.48   26103.43    34022.58     44124.88    73424.69
#  4      단기금융상품        435       1440         255        11340    37939.04
#  ..        ...        ...        ...         ...          ...         ...
#  71     매출액증가율        NaN        NaN         NaN          NaN         NaN
#  72    영업이익증가율        NaN  33.937167   20.889506  2071.389788  181.238495
#  73  EBITDA증가율        NaN  59.872019  122.437843   204.325908  212.289268
#  74     EPS증가율        NaN        NaN         NaN          NaN         NaN
#  75     BPS증가율        NaN        NaN         NaN          NaN         NaN
#
#  [76 rows x 6 columns],
#  'SK아이테크놀로지(연결)':           항목명 2018       2019        2020        2021        2022
#  0        자산총계    0   780246.1  1991629.07  3184524.11  3497335.37
#  1        유동자산    0  182519.62   566775.18  1239411.88   853496.75
#  2    현금및현금성자산    0   24056.05   208164.19   235653.99   462679.88
#  3        매출채권    0   48461.09    77023.23   115260.14   126056.57
#  4      단기금융상품    0   69214.56   158934.43   737860.53    86590.21
#  ..        ...  ...        ...         ...         ...         ...
#  71     매출액증가율  NaN        NaN         NaN         NaN         NaN
#  72    영업이익증가율  NaN        NaN  155.443104   71.215873  -58.643157
#  73  EBITDA증가율  NaN        NaN  162.268678  115.241244   50.392288
#  74     EPS증가율  NaN        NaN         NaN         NaN         NaN
#  75     BPS증가율  NaN        NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  'SKC(연결)':           항목명        2018        2019        2020        2021        2022
#  0        자산총계  3833128.68  3972988.75  5406405.84   6180132.5  6393092.56
#  1        유동자산   910124.83   992719.76   1247268.1  1820030.59  2526145.05
#  2    현금및현금성자산   160388.22    79957.91   428586.45    722154.8  1098442.06
#  3        매출채권    338638.6   372574.48   398637.91   471114.67   388081.44
#  4      단기금융상품        0.19       10.19      938.02     6949.05      366000
#  ..        ...         ...         ...         ...         ...         ...
#  71     매출액증가율         NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율         NaN   69.485204  144.550606  198.723333   54.864509
#  73  EBITDA증가율         NaN    71.50337  197.835346  129.499137    76.56271
#  74     EPS증가율         NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율         NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '롯데에너지머티리얼즈(연결)':           항목명       2018        2019        2020        2021        2022
#  0        자산총계  692206.04   1036928.1  1081009.99  1753565.09   2430279.8
#  1        유동자산  357483.18   592714.09   518895.36   959410.93     1436348
#  2    현금및현금성자산   53097.28   332997.04   136680.46   234580.12   200611.63
#  3        매출채권    63847.6     71418.2    98300.21   153217.97   134084.07
#  4      단기금융상품   22000.18           0       14100     3284.27    22808.53
#  ..        ...        ...         ...         ...         ...         ...
#  71     매출액증가율        NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율        NaN   96.160622  108.579537  137.460409  121.233066
#  73  EBITDA증가율        NaN  115.835553   88.846765   155.58664  101.547455
#  74     EPS증가율        NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율        NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '솔루스첨단소재(연결)':           항목명 2018       2019        2020        2021        2022
#  0        자산총계    0  494200.18   841168.49  1011599.75  1461040.41
#  1        유동자산    0  230551.46   450375.92   394470.44   507979.82
#  2    현금및현금성자산    0   94646.28    305601.6   139587.73   162773.47
#  3        매출채권    0   54730.78    55605.42    77369.97    90797.82
#  4      단기금융상품    0          0          30           0           0
#  ..        ...  ...        ...         ...         ...         ...
#  71     매출액증가율  NaN        NaN         NaN         NaN         NaN
#  72    영업이익증가율  NaN        NaN  298.504411   16.468376 -903.452831
#  73  EBITDA증가율  NaN        NaN  209.870496   186.68391   40.770501
#  74     EPS증가율  NaN        NaN         NaN         NaN         NaN
#  75     BPS증가율  NaN        NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '엘앤에프(연결)':           항목명       2018       2019       2020         2021        2022
#  0        자산총계  330981.61  416201.28   466217.4   1532199.43  3023932.97
#  1        유동자산  199012.04  206225.29  212043.54   1070617.28  2302551.79
#  2    현금및현금성자산   11371.56     828.39   21225.33    271776.32   120198.63
#  3        매출채권   49138.63   57388.91   59076.14    268241.21   797106.77
#  4      단기금융상품     2356.2    2381.73   17051.61       213000        2300
#  ..        ...        ...        ...        ...          ...         ...
#  71     매출액증가율        NaN        NaN        NaN          NaN         NaN
#  72    영업이익증가율        NaN -28.358216  -19.18427  3010.333943  601.825378
#  73  EBITDA증가율        NaN  11.699109  32.336387 -6216.831194 -417.083672
#  74     EPS증가율        NaN        NaN        NaN          NaN         NaN
#  75     BPS증가율        NaN        NaN        NaN          NaN         NaN
#
#  [76 rows x 6 columns],
#  '대주전자재료(연결)':           항목명       2018       2019        2020        2021       2022
#  0        자산총계  173395.38  191226.39   206009.39   298387.22  327888.92
#  1        유동자산   55049.23   61613.27     69476.7   116634.65  128041.01
#  2    현금및현금성자산   15143.26   11420.71    18819.72    34262.74   66805.29
#  3        매출채권    17651.2   22962.48    27708.14    36433.39   29572.45
#  4      단기금융상품    4206.72     648.41      670.44    12547.63    2547.63
#  ..        ...        ...        ...         ...         ...        ...
#  71     매출액증가율        NaN        NaN         NaN         NaN        NaN
#  72    영업이익증가율        NaN  71.196259   338.74272   195.04757  68.031743
#  73  EBITDA증가율        NaN  92.163983  204.231656  190.161885  63.151312
#  74     EPS증가율        NaN        NaN         NaN         NaN        NaN
#  75     BPS증가율        NaN        NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '엔켐(연결)':           항목명      2018        2019       2020        2021        2022
#  0        자산총계  57420.34   131200.26  199012.52   407420.79   680249.51
#  1        유동자산  32552.91    88845.77  126667.51   242074.06   342244.96
#  2    현금및현금성자산   7793.76    32122.67   34471.34    81511.61    33319.25
#  3        매출채권   7350.83     26287.7   42471.81    63100.24   122896.36
#  4      단기금융상품    937.34      970.73   13678.82         420         420
#  ..        ...       ...         ...        ...         ...         ...
#  71     매출액증가율       NaN         NaN        NaN         NaN         NaN
#  72    영업이익증가율       NaN  485.621501  98.830307 -207.315589  -59.163434
#  73  EBITDA증가율       NaN  288.555503  93.728472 -185.759176 -310.227382
#  74     EPS증가율       NaN         NaN        NaN         NaN         NaN
#  75     BPS증가율       NaN         NaN        NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '천보(연결)':           항목명       2018        2019        2020        2021        2022
#  0        자산총계  134748.07   235236.92    260701.3   403737.99   818655.92
#  1        유동자산   71926.01   153243.76   140142.54   226884.93   439441.99
#  2    현금및현금성자산    8205.49     6990.79    13493.03    35333.55    64765.78
#  3        매출채권   22935.38    22836.35    32372.02    58867.75     57450.4
#  4      단기금융상품   10986.31    85176.59    47142.98    26415.31   201197.83
#  ..        ...        ...         ...         ...         ...         ...
#  71     매출액증가율        NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율        NaN  100.574506  110.795791  168.024648  111.542575
#  73  EBITDA증가율        NaN  100.647032  114.928024  175.531502   82.648705
#  74     EPS증가율        NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율        NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '솔브레인(연결)':           항목명 2018 2019       2020        2021        2022
#  0        자산총계  NaN  NaN  717745.27   829946.54   934907.22
#  1        유동자산  NaN  NaN  368191.64   438576.24    458877.3
#  2    현금및현금성자산  NaN  NaN  184120.57   168689.08   167741.41
#  3        매출채권  NaN  NaN   82521.28   125948.33    66676.67
#  4      단기금융상품  NaN  NaN      10000           0    63287.78
#  ..        ...  ...  ...        ...         ...         ...
#  71     매출액증가율  NaN  NaN        NaN         NaN         NaN
#  72    영업이익증가율  NaN  NaN        NaN  181.652905  109.643079
#  73  EBITDA증가율  NaN  NaN        NaN  227.230051  105.691675
#  74     EPS증가율  NaN  NaN        NaN         NaN         NaN
#  75     BPS증가율  NaN  NaN        NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '동화기업(연결)':           항목명        2018        2019        2020        2021        2022
#  0        자산총계  1229786.59  1440636.41  1586439.71  1770876.76  1846108.23
#  1        유동자산   282922.15   324902.11   366460.47    453522.5   421219.49
#  2    현금및현금성자산    24135.66    21581.71   366460.47    31302.21    31147.66
#  3        매출채권    93519.03    93823.06    85863.27   105660.16   104428.02
#  4      단기금융상품        9399    35335.34    33485.53     63609.7    43569.41
#  ..        ...         ...         ...         ...         ...         ...
#  71     매출액증가율         NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율         NaN   69.535392  114.290444  157.015969   69.033961
#  73  EBITDA증가율         NaN   92.159558  108.016278  121.112367   101.14492
#  74     EPS증가율         NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율         NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '피엔티(연결)':           항목명       2018       2019         2020        2021        2022
#  0        자산총계  290894.93  500330.95    435428.13   576359.32  1087892.46
#  1        유동자산  236784.42  411159.98    295121.13   437391.81    915394.2
#  2    현금및현금성자산    6904.53    4218.92     14679.09    30854.04    16223.57
#  3        매출채권   26044.49   43350.19     48824.02    60240.42    44475.41
#  4      단기금융상품          0          0            0           0           0
#  ..        ...        ...        ...          ...         ...         ...
#  71     매출액증가율        NaN        NaN          NaN         NaN         NaN
#  72    영업이익증가율        NaN  39.363485    3742.1152   98.387168  142.928794
#  73  EBITDA증가율        NaN  27.247146  1846.605761  155.292938  102.182618
#  74     EPS증가율        NaN        NaN          NaN         NaN         NaN
#  75     BPS증가율        NaN        NaN          NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '씨아이에스(연결)':           항목명       2018        2019       2020        2021       2022
#  0        자산총계  167266.43           0          0   319224.58  443995.11
#  1        유동자산  139768.14           0          0   236115.84  346206.53
#  2    현금및현금성자산    4767.39           0          0    62836.39  103671.33
#  3        매출채권   26771.96           0          0     12759.6   14483.27
#  4      단기금융상품          0           0          0           0          0
#  ..        ...        ...         ...        ...         ...        ...
#  71     매출액증가율        NaN         NaN        NaN         NaN        NaN
#  72    영업이익증가율        NaN        -0.0        NaN         NaN  47.768092
#  73  EBITDA증가율        NaN -160.135655 -15.606182  788.108231 -97.913837
#  74     EPS증가율        NaN         NaN        NaN         NaN        NaN
#  75     BPS증가율        NaN         NaN        NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '탑엔지니어링(연결)':           항목명       2018        2019       2020        2021        2022
#  0        자산총계  556986.12   596075.36  618832.26    629496.2   512615.06
#  1        유동자산  310632.33   343391.27  338343.37   356975.02   282936.68
#  2    현금및현금성자산   41927.76    53050.36   46224.13    53129.45    36111.57
#  3        매출채권  130591.19   150452.04   160454.9    145677.1   108305.55
#  4      단기금융상품    4788.42      748.68     615.46      663.55      812.82
#  ..        ...        ...         ...        ...         ...         ...
#  71     매출액증가율        NaN         NaN        NaN         NaN         NaN
#  72    영업이익증가율        NaN  208.256554 -25.763399  112.368002  139.396213
#  73  EBITDA증가율        NaN   178.88902  11.598922   169.58708   37.675401
#  74     EPS증가율        NaN         NaN        NaN         NaN         NaN
#  75     BPS증가율        NaN         NaN        NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '지아이텍(별도)':           항목명      2018        2019        2020       2021        2022
#  0        자산총계  22765.86    25080.22    33580.61   63933.75    76289.35
#  1        유동자산   5792.51     8495.07    15041.67   39389.32     42194.5
#  2    현금및현금성자산    846.21     2270.14      5482.1    3855.01     5228.97
#  3        매출채권   3350.78     4695.57     4094.15    7361.65    16140.86
#  4      단기금융상품      9.45        11.9           0          0           0
#  ..        ...       ...         ...         ...        ...         ...
#  71     매출액증가율       NaN         NaN         NaN        NaN         NaN
#  72    영업이익증가율       NaN  363.695761  270.709537  80.410463  162.849545
#  73  EBITDA증가율       NaN  134.344109  178.875513  98.113789  132.876051
#  74     EPS증가율       NaN         NaN         NaN        NaN         NaN
#  75     BPS증가율       NaN         NaN         NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '하나기술(연결)':           항목명      2018        2019        2020        2021        2022
#  0        자산총계  69584.49   101598.99   119465.05   189112.71   232243.53
#  1        유동자산  32123.16    43620.68    68141.03   129453.05   110297.63
#  2    현금및현금성자산   7477.94    13968.83    33799.11    60532.83    32516.93
#  3        매출채권   1984.47     4782.08     5903.89    31902.53    12370.32
#  4      단기금융상품    1000.1     5061.25           0           0     8511.09
#  ..        ...       ...         ...         ...         ...         ...
#  71     매출액증가율       NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율       NaN  125.472321  -78.535076  110.002306 -225.539531
#  73  EBITDA증가율       NaN  133.012785 -532.661708    7.647686  -86.626944
#  74     EPS증가율       NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율       NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '엠플러스(연결)':           항목명 2018       2019        2020        2021        2022
#  0        자산총계    0  142053.85      140917   178269.38   321323.14
#  1        유동자산    0  104637.52   101216.65   136711.58   268999.43
#  2    현금및현금성자산    0     3881.7      3311.3      4923.1    11518.44
#  3        매출채권    0   25867.52    10276.37    14562.86    27674.38
#  4      단기금융상품    0         50           0           0           0
#  ..        ...  ...        ...         ...         ...         ...
#  71     매출액증가율  NaN        NaN         NaN         NaN         NaN
#  72    영업이익증가율  NaN        NaN  366.936942 -139.537453   70.312226
#  73  EBITDA증가율  NaN  113.04548  250.410612 -113.870909  170.686587
#  74     EPS증가율  NaN        NaN         NaN         NaN         NaN
#  75     BPS증가율  NaN        NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '유일에너테크(연결)':           항목명      2018         2019       2020       2021        2022
#  0        자산총계  34319.66     62942.79   40771.17   88853.26   156003.23
#  1        유동자산  26764.96      52668.2      27700   64452.05    62302.55
#  2    현금및현금성자산   4471.63      5204.74    3253.06    1197.63     7632.74
#  3        매출채권    844.54     11976.54    6627.83    5429.92     6688.45
#  4      단기금융상품   1476.79      1960.79        100        100         100
#  ..        ...       ...          ...        ...        ...         ...
#  71     매출액증가율       NaN          NaN        NaN        NaN         NaN
#  72    영업이익증가율       NaN -1068.030913  67.671207 -75.397746   331.46531
#  73  EBITDA증가율       NaN  -840.822299  50.895226 -67.629301 -711.262178
#  74     EPS증가율       NaN          NaN        NaN        NaN         NaN
#  75     BPS증가율       NaN          NaN        NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '디이엔티(연결)':           항목명      2018       2019        2020       2021        2022
#  0        자산총계  60037.16   46017.81    52009.09   59867.35    89051.97
#  1        유동자산  23228.52   17181.16    24491.95   30373.71    49011.64
#  2    현금및현금성자산   3283.64     1204.9    11583.81    7050.24    25784.65
#  3        매출채권   5691.34    3623.78     2464.84    18947.7      4550.7
#  4      단기금융상품         0          0     2047.98          0           0
#  ..        ...       ...        ...         ...        ...         ...
#  71     매출액증가율       NaN        NaN         NaN        NaN         NaN
#  72    영업이익증가율       NaN   54.11058   96.095664 -19.211141 -380.877083
#  73  EBITDA증가율       NaN  57.406493  182.757026   -32.2215 -118.114929
#  74     EPS증가율       NaN        NaN         NaN        NaN         NaN
#  75     BPS증가율       NaN        NaN         NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '디에이테크놀로지(연결)':           항목명       2018       2019         2020       2021        2022
#  0        자산총계  157728.82  122217.45    130453.87  148383.49   131393.12
#  1        유동자산   95993.49   63736.63     76621.78   94584.85    87630.23
#  2    현금및현금성자산   39331.15    16823.5         9497   12516.64     1675.15
#  3        매출채권    17021.6   14929.29     13948.25   10338.55    10604.11
#  4      단기금융상품     145.43       2150     11286.15   19225.59     7917.45
#  ..        ...        ...        ...          ...        ...         ...
#  71     매출액증가율        NaN        NaN          NaN        NaN         NaN
#  72    영업이익증가율        NaN  30.818275 -2109.116638  92.717911  139.406677
#  73  EBITDA증가율        NaN  99.680832   141.280074  59.406455  183.623964
#  74     EPS증가율        NaN        NaN          NaN        NaN         NaN
#  75     BPS증가율        NaN        NaN          NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '원익피앤이(연결)':           항목명      2018        2019        2020        2021       2022
#  0        자산총계  73013.62   107444.75    95614.58   404336.38  411777.28
#  1        유동자산  51712.58    85971.31    72292.58   404336.38  263743.35
#  2    현금및현금성자산  11835.01    23071.82    18490.41    50678.33   17410.19
#  3        매출채권   9231.59    17791.87    22066.79    50820.42    66841.1
#  4      단기금융상품         0           0      2393.6          90          0
#  ..        ...       ...         ...         ...         ...        ...
#  71     매출액증가율       NaN         NaN         NaN         NaN        NaN
#  72    영업이익증가율       NaN  185.641432  122.642416  219.403592  26.393908
#  73  EBITDA증가율       NaN   147.39275    92.20721  275.223513  53.012363
#  74     EPS증가율       NaN         NaN         NaN         NaN        NaN
#  75     BPS증가율       NaN         NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '에이프로(연결)':           항목명      2018        2019       2020        2021       2022
#  0        자산총계  36243.95    49662.22   74145.86   100128.87  140254.12
#  1        유동자산  30807.29    40373.32    57893.2     73665.7     104082
#  2    현금및현금성자산    9361.8    13875.24   15070.37    10328.64   25321.43
#  3        매출채권   8737.54    12086.16    2920.73    23769.12   13635.64
#  4      단기금융상품       200         260   14132.27       12000     466.96
#  ..        ...       ...         ...        ...         ...        ...
#  71     매출액증가율       NaN         NaN        NaN         NaN        NaN
#  72    영업이익증가율       NaN  144.210528   10.51855 -442.052926  52.089625
#  73  EBITDA증가율       NaN  156.340818  17.008236 -141.578868  31.889043
#  74     EPS증가율       NaN         NaN        NaN         NaN        NaN
#  75     BPS증가율       NaN         NaN        NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '삼지전자(연결)':           항목명       2018        2019        2020        2021       2022
#  0        자산총계  567955.33   559512.18   613137.09   816261.26  993238.73
#  1        유동자산  353257.07   334011.42   383870.82   638215.42  770787.81
#  2    현금및현금성자산   22646.13     46396.1    65448.93    76485.25   71187.62
#  3        매출채권  127783.76   139243.86    161261.1   297182.06  326017.94
#  4      단기금융상품    4687.17      883.73     1263.43     1766.97    1673.58
#  ..        ...        ...         ...         ...         ...        ...
#  71     매출액증가율        NaN         NaN         NaN         NaN        NaN
#  72    영업이익증가율        NaN   111.50991  132.819967  196.235965  93.797779
#  73  EBITDA증가율        NaN  104.376094  141.169559  151.802312  98.217584
#  74     EPS증가율        NaN         NaN         NaN         NaN        NaN
#  75     BPS증가율        NaN         NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '대보마그네틱(연결)':           항목명 2018        2019      2020         2021        2022
#  0        자산총계    0           0         0            0   100953.17
#  1        유동자산    0           0         0            0    68525.52
#  2    현금및현금성자산    0           0         0            0    37363.79
#  3        매출채권    0           0         0            0    15049.55
#  4      단기금융상품    0           0         0            0           0
#  ..        ...  ...         ...       ...          ...         ...
#  71     매출액증가율  NaN         NaN       NaN          NaN         NaN
#  72    영업이익증가율  NaN         NaN       NaN          NaN         NaN
#  73  EBITDA증가율  NaN  110.619491 -3.435402 -4454.677033  374.469471
#  74     EPS증가율  NaN         NaN       NaN          NaN         NaN
#  75     BPS증가율  NaN         NaN       NaN          NaN         NaN
#
#  [76 rows x 6 columns],
#  '엔시스(연결)':           항목명 2018       2019        2020        2021       2022
#  0        자산총계    0          0    27837.42    69806.55   83704.14
#  1        유동자산    0          0    21730.89    54263.23   43911.12
#  2    현금및현금성자산    0          0      1317.9    10190.74     6618.2
#  3        매출채권    0          0     8930.56    11474.75    7193.22
#  4      단기금융상품    0          0         602       20000   11138.08
#  ..        ...  ...        ...         ...         ...        ...
#  71     매출액증가율  NaN        NaN         NaN         NaN        NaN
#  72    영업이익증가율  NaN        NaN         NaN  103.822564  52.723277
#  73  EBITDA증가율  NaN  67.519567  177.330503  114.083723  61.642345
#  74     EPS증가율  NaN        NaN         NaN         NaN        NaN
#  75     BPS증가율  NaN        NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '파인텍(연결)':           항목명       2018         2019        2020       2021        2022
#  0        자산총계  103303.84     120241.7    100234.1   78192.59    77684.36
#  1        유동자산   35962.17     53511.23    56374.18   41418.27    41112.89
#  2    현금및현금성자산    5129.36      5740.63     8092.42   11458.77     5937.57
#  3        매출채권   19082.66     25956.88    25912.45   13481.53    13752.55
#  4      단기금융상품     1773.4      2576.96     4904.78    4312.83     3363.13
#  ..        ...        ...          ...         ...        ...         ...
#  71     매출액증가율        NaN          NaN         NaN        NaN         NaN
#  72    영업이익증가율        NaN  1001.431147   -162.7176 -32.007455  360.143464
#  73  EBITDA증가율        NaN    66.919641 -227.755871   -52.1394  166.035003
#  74     EPS증가율        NaN          NaN         NaN        NaN         NaN
#  75     BPS증가율        NaN          NaN         NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '디아이티(연결)':           항목명       2018        2019       2020       2021        2022
#  0        자산총계  302071.99   289657.41  337916.81  319094.68   254842.47
#  1        유동자산  259478.45   246946.37  292608.72  270936.97   200308.84
#  2    현금및현금성자산   27912.64    34903.92   33489.48   22149.74    15507.23
#  3        매출채권    3703.65     8616.58    11743.9    16243.8     7465.98
#  4      단기금융상품   106252.1    95437.55   91942.23   93071.21   101861.75
#  ..        ...        ...         ...        ...        ...         ...
#  71     매출액증가율        NaN         NaN        NaN        NaN         NaN
#  72    영업이익증가율        NaN  226.978154 -14.689449  304.90835  -93.877921
#  73  EBITDA증가율        NaN  184.236697  -9.128447  93.002508 -952.010523
#  74     EPS증가율        NaN         NaN        NaN        NaN         NaN
#  75     BPS증가율        NaN         NaN        NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '이노메트리(연결)':           항목명      2018       2019       2020       2021        2022
#  0        자산총계   59657.4   61620.37   55477.53    67592.5    80018.44
#  1        유동자산  52774.76   50974.16   37943.34    34535.6    60000.97
#  2    현금및현금성자산  36981.14    6442.95   15735.13    4973.67       14094
#  3        매출채권   3592.74    10894.5    7015.06   11451.86     8201.69
#  4      단기금융상품      3127      17045       2150       2090     7122.76
#  ..        ...       ...        ...        ...        ...         ...
#  71     매출액증가율       NaN        NaN        NaN        NaN         NaN
#  72    영업이익증가율       NaN  79.351314 -83.239116 -56.730325  149.919092
#  73  EBITDA증가율       NaN  89.182971 -77.561938 -95.589485  105.037692
#  74     EPS증가율       NaN        NaN        NaN        NaN         NaN
#  75     BPS증가율       NaN        NaN        NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '브이원텍(연결)':           항목명      2018       2019       2020        2021       2022
#  0        자산총계  81944.44   87282.33    93630.5   132415.97  175413.39
#  1        유동자산  70198.72    62998.6   50823.94    60177.82   69388.06
#  2    현금및현금성자산  17200.08   13610.06   10244.44    12888.22   11175.08
#  3        매출채권   3324.46    4691.67    5454.27     7203.22   11445.51
#  4      단기금융상품         0          0          0           0          0
#  ..        ...       ...        ...        ...         ...        ...
#  71     매출액증가율       NaN        NaN        NaN         NaN        NaN
#  72    영업이익증가율       NaN   30.72785  135.41829   76.156112   0.765688
#  73  EBITDA증가율       NaN  40.798925  80.509225  224.814137 -18.935349
#  74     EPS증가율       NaN        NaN        NaN         NaN        NaN
#  75     BPS증가율       NaN        NaN        NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '인텍플러스(연결)':           항목명      2018       2019        2020        2021       2022
#  0        자산총계  30307.81   42130.08    52622.82   107364.09  116215.73
#  1        유동자산  17869.56    29190.2    35790.49    89569.23   87305.01
#  2    현금및현금성자산   4080.93    5885.84     6653.69    14215.77    9994.37
#  3        매출채권   1164.84    7381.89    14242.63    40131.17    38398.5
#  4      단기금융상품      3260       4110        2040       23.02       2000
#  ..        ...       ...        ...         ...         ...        ...
#  71     매출액증가율       NaN        NaN         NaN         NaN        NaN
#  72    영업이익증가율       NaN -56.561724  149.150061  392.270943  70.331811
#  73  EBITDA증가율       NaN -88.484925  145.172389  380.215322  69.580331
#  74     EPS증가율       NaN        NaN         NaN         NaN        NaN
#  75     BPS증가율       NaN        NaN         NaN         NaN        NaN
#
#  [76 rows x 6 columns],
#  '코윈테크(연결)':           항목명 2018        2019       2020         2021        2022
#  0        자산총계  NaN   115217.98  127280.65    186416.43   343813.99
#  1        유동자산  NaN    89227.83   89551.99    120176.48   251294.23
#  2    현금및현금성자산  NaN    16520.06   18503.01     42041.83    37544.42
#  3        매출채권  NaN    33616.28   15828.85     33311.14    42311.62
#  4      단기금융상품  NaN       13000      24044         9180    53399.28
#  ..        ...  ...         ...        ...          ...         ...
#  71     매출액증가율  NaN         NaN        NaN          NaN         NaN
#  72    영업이익증가율  NaN         NaN   3.015206  1052.578074  223.414835
#  73  EBITDA증가율  NaN  179.057703  11.494369   469.479696  154.493381
#  74     EPS증가율  NaN         NaN        NaN          NaN         NaN
#  75     BPS증가율  NaN         NaN        NaN          NaN         NaN
#
#  [76 rows x 6 columns],
#  '에스에프에이(연결)':           항목명        2018        2019        2020        2021        2022
#  0        자산총계  1660531.82  1805907.17  1799395.63  1904444.38  1925346.83
#  1        유동자산   958567.88  1098458.55  1084226.54  1126475.08  1189685.41
#  2    현금및현금성자산   329313.71    208984.4   422533.93   277023.48   180176.36
#  3        매출채권   167445.55   209987.99   203322.84   223296.45   231633.14
#  4      단기금융상품    74846.97    74178.57    74620.45    94339.57    57943.38
#  ..        ...         ...         ...         ...         ...         ...
#  71     매출액증가율         NaN         NaN         NaN         NaN         NaN
#  72    영업이익증가율         NaN   91.401188   78.118195  112.911433   85.170769
#  73  EBITDA증가율         NaN    90.50875    84.64567  106.226397   87.285703
#  74     EPS증가율         NaN         NaN         NaN         NaN         NaN
#  75     BPS증가율         NaN         NaN         NaN         NaN         NaN
#
#  [76 rows x 6 columns],
#  '아바코(연결)':           항목명       2018        2019       2020       2021        2022
#  0        자산총계  212793.72   198606.31     210178  263748.82   278436.19
#  1        유동자산  172596.58   145115.13  148975.49     193345   194164.69
#  2    현금및현금성자산   10444.97    18571.41   71375.16   30703.64    20674.77
#  3        매출채권   43360.49    28954.65   13546.12    71003.4    32558.63
#  4      단기금융상품     4662.2    15013.95    14950.9   34842.85     27770.5
#  ..        ...        ...         ...        ...        ...         ...
#  71     매출액증가율        NaN         NaN        NaN        NaN         NaN
#  72    영업이익증가율        NaN  102.051793  98.881495   42.51459  138.334633
#  73  EBITDA증가율        NaN   81.158513  75.147157  81.350403   118.81219
#  74     EPS증가율        NaN         NaN        NaN        NaN         NaN
#  75     BPS증가율        NaN         NaN        NaN        NaN         NaN
#
#  [76 rows x 6 columns],
#  '에스엠코어(연결)':           항목명       2018         2019       2020       2021        2022
#  0        자산총계  105559.79     99760.64   92894.96   92845.27   109853.67
#  1        유동자산   78142.47     76919.38   71350.02   72324.28    90155.29
#  2    현금및현금성자산   22339.13     14451.21   29573.87   10612.78    10969.04
#  3        매출채권   24788.51     23323.05    18615.6   16039.87     37171.3
#  4      단기금융상품          0            0    3506.25    3506.25     3506.25
#  ..        ...        ...          ...        ...        ...         ...
#  71     매출액증가율        NaN          NaN        NaN        NaN         NaN
#  72    영업이익증가율        NaN  1699.907485  40.408747 -159.64649   -80.70857
#  73  EBITDA증가율        NaN   266.069068  41.382045  86.729055  225.111924
#  74     EPS증가율        NaN          NaN        NaN        NaN         NaN
#  75     BPS증가율        NaN          NaN        NaN        NaN         NaN
#
#  [76 rows x 6 columns]}

# %%
data['엘지에너지솔루션(연결)']
# Out:
#           항목명 2018 2019      2020        2021        2022
# 0        자산총계    0    0  19941795    23764137    38299445
# 1        유동자산    0    0   9085706     9535827    18804269
# 2    현금및현금성자산    0    0   1493145     1282880     5937967
# 3        매출채권    0    0   2931150     2914458     4771846
# 4      단기금융상품    0    0    600000        1067           0
# ..        ...  ...  ...       ...         ...         ...
# 71     매출액증가율  NaN  NaN       NaN         NaN         NaN
# 72    영업이익증가율  NaN  NaN       NaN -161.713026  157.939672
# 73  EBITDA증가율  NaN  NaN       NaN  -471.65929  123.080255
# 74     EPS증가율  NaN  NaN       NaN         NaN         NaN
# 75     BPS증가율  NaN  NaN       NaN         NaN         NaN
#
# [76 rows x 6 columns]

# %%
domain_map = pd.read_csv('../data/domain_map.csv')

# %%
nested_dict = {}
for _, row in domain_map.iterrows():
    category = row['category']
    division = row['division']
    sub = row['sub']
    name = row['name']
    percent = row['percent']

    category_dict = nested_dict.setdefault(category, [])
    division_dict = next((item for item in category_dict if item['division'] == division and item['sub'] == sub), None)
    if not division_dict:
        division_dict = {'division': division, 'sub': sub, 'contents': []}
        category_dict.append(division_dict)

    division_dict['contents'].append({'name': name, 'percent': percent})

nested_dict
# Out:
# {'자원생산': [{'division': '리튬',
#    'sub': '희귀',
#    'contents': [{'name': '아르헨티나', 'percent': 37.0},
#     {'name': '호주', 'percent': 23.0},
#     {'name': '칠레', 'percent': 22.0},
#     {'name': '중국', 'percent': 11.0},
#     {'name': '볼리비아', 'percent': 7.0}]},
#   {'division': '니켈',
#    'sub': '지역편중',
#    'contents': [{'name': '인도네시아', 'percent': 21.0},
#     {'name': '필리핀', 'percent': 19.0},
#     {'name': '러시아', 'percent': 11.0},
#     {'name': '캐나다', 'percent': 9.0},
#     {'name': '가나', 'percent': 9.0}]},
#   {'division': '코발트',
#    'sub': '희귀',
#    'contents': [{'name': '콩고', 'percent': 60.0},
#     {'name': '러시아', 'percent': 10.0},
#     {'name': '인도네시아', 'percent': 9.0},
#     {'name': '몽골', 'percent': 7.0},
#     {'name': '캐나다', 'percent': 6.0}]},
#   {'division': '망간',
#    'sub': '희소',
#    'contents': [{'name': '중국', 'percent': 53.0},
#     {'name': '남아프리카', 'percent': 22.0},
#     {'name': '가나', 'percent': 10.0},
#     {'name': '호주', 'percent': 8.0},
#     {'name': '인도', 'percent': 4.0}]},
#   {'division': '흑연',
#    'sub': nan,
#    'contents': [{'name': '중국', 'percent': 44.0}]},
#   {'division': '흑연',
#    'sub': nan,
#    'contents': [{'name': '브라질', 'percent': 15.0}]},
#   {'division': '흑연',
#    'sub': nan,
#    'contents': [{'name': '러시아', 'percent': 9.0}]},
#   {'division': '흑연', 'sub': nan, 'contents': [{'name': '인도', 'percent': 7.0}]},
#   {'division': '흑연', 'sub': nan, 'contents': [{'name': '호주', 'percent': 5.0}]},
#   {'division': '실리콘',
#    'sub': nan,
#    'contents': [{'name': '중국', 'percent': 59.0}]},
#   {'division': '실리콘',
#    'sub': nan,
#    'contents': [{'name': '미국', 'percent': 15.0}]},
#   {'division': '실리콘',
#    'sub': nan,
#    'contents': [{'name': '일본', 'percent': 9.0}]},
#   {'division': '실리콘',
#    'sub': nan,
#    'contents': [{'name': '독일', 'percent': 6.5}]},
#   {'division': '실리콘',
#    'sub': nan,
#    'contents': [{'name': '러시아', 'percent': 4.5}]}],
#  '원자재 가공': [{'division': '탄산/수산화 리튬',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]},
#   {'division': '니켈 정련',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]},
#   {'division': '코발트 정련',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]},
#   {'division': '구형흑연',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]},
#   {'division': '실리콘복합산화물',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]}],
#  '중간재 생산': [{'division': '양극재',
#    'sub': '시장규모',
#    'contents': [{'name': '포스코퓨처엠', 'percent': nan},
#     {'name': '에코프로비엠', 'percent': nan}]},
#   {'division': '음극제',
#    'sub': '시장규모',
#    'contents': [{'name': '포스코퓨처엠', 'percent': nan},
#     {'name': '대주전자재료', 'percent': nan},
#     {'name': '한솔케미칼', 'percent': nan}]},
#   {'division': '전해액/질',
#    'sub': '시장규모',
#    'contents': [{'name': '엔켐', 'percent': nan},
#     {'name': '천보', 'percent': nan},
#     {'name': '솔브레인', 'percent': nan},
#     {'name': '후성', 'percent': nan},
#     {'name': '동화기업', 'percent': nan}]},
#   {'division': '분리막',
#    'sub': '시장규모',
#    'contents': [{'name': '에스케이아이이테크놀로지', 'percent': nan}]},
#   {'division': '동박',
#    'sub': '시장규모',
#    'contents': [{'name': 'SKC', 'percent': nan},
#     {'name': '롯데에너지머티리얼즈', 'percent': nan},
#     {'name': '솔루스첨단소재', 'percent': nan}]}],
#  '설비/장비 공급': [{'division': '공정장비',
#    'sub': '시장규모',
#    'contents': [{'name': '피엔티', 'percent': nan},
#     {'name': '씨아이에스', 'percent': nan},
#     {'name': '탐엔지니어링', 'percent': nan},
#     {'name': '지아이텍', 'percent': nan},
#     {'name': '하나기술', 'percent': nan},
#     {'name': '엠플러스', 'percent': nan},
#     {'name': '유일에너테크', 'percent': nan},
#     {'name': '디이엔티', 'percent': nan},
#     {'name': '디에이테크놀로지', 'percent': nan},
#     {'name': '디에이테크놀로지', 'percent': nan},
#     {'name': '원익피앤이', 'percent': nan},
#     {'name': '에이프로', 'percent': nan},
#     {'name': '삼지전자', 'percent': nan},
#     {'name': '하나기술', 'percent': nan},
#     {'name': '대보마그네틱', 'percent': nan}]},
#   {'division': '자동화장비',
#    'sub': '시장규모',
#    'contents': [{'name': '코윈테크', 'percent': nan},
#     {'name': '에스에프에이', 'percent': nan},
#     {'name': '아바코', 'percent': nan},
#     {'name': '에스엠코어', 'percent': nan}]},
#   {'division': '검사장비',
#    'sub': '시장규모',
#    'contents': [{'name': '엔시스', 'percent': nan},
#     {'name': '파인텍', 'percent': nan},
#     {'name': '디아이티', 'percent': nan},
#     {'name': '넥스타테크놀로지', 'percent': nan},
#     {'name': '이노메트리', 'percent': nan},
#     {'name': '브이원텍', 'percent': nan},
#     {'name': '파비스', 'percent': nan},
#     {'name': '인텍플러스', 'percent': nan},
#     {'name': '뷰온', 'percent': nan}]}],
#  '최종재 생산': [{'division': '배터리',
#    'sub': '시장규모',
#    'contents': [{'name': '엘지에너지솔루션', 'percent': nan},
#     {'name': '에스케이온', 'percent': nan},
#     {'name': '삼성 SDI', 'percent': nan}]}],
#  '타겟 세그먼트': [{'division': '전기차',
#    'sub': '시장규모',
#    'contents': [{'name': '테슬라', 'percent': nan}]},
#   {'division': 'ESS',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]},
#   {'division': 'IT기기',
#    'sub': '시장규모',
#    'contents': [{'name': '애플', 'percent': nan},
#     {'name': '삼성전자', 'percent': nan}]},
#   {'division': '기타',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]}],
#  '폐기 및 재활용': [{'division': '재활용',
#    'sub': '시장규모',
#    'contents': [{'name': nan, 'percent': nan}]}]}

# %%
for n in nested_dict:
    print(n)
# Out:
# 자원생산
# 원자재 가공
# 중간재 생산
# 설비/장비 공급
# 최종재 생산
# 타겟 세그먼트
# 폐기 및 재활용
